# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('DATA/text.jpg',0)
plt.imshow(img,cmap='gray')

ret,thresh = cv2.threshold(img,90,255,cv2.THRESH_BINARY,)

plt.imshow(thresh,cmap='gray')

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Dintr-odata, unchiagul izbueni in pling, F
# tremure, buzele-i batrine se incordara si ‘bat si
# hohoteasci rigusit. Maica veni repede lings da
# cu bratul. fl ridicad in Picioare, incordindu-
# jumatate il tiri, jumatate il spr
#
# si Sil cup,
# ijini cAtre cort, a
#
# — Trebuie s&-i fie rau tare, zise unchiul John oy ake
# el pe lume n-a facut una ca asta. N-am apucat nici e (aT
# vad bocind. Clodata 4 po if 2
# Apoi sari pe platforma si arunca jos o saltea, Maica ; G0 a
# din cort, se apropie de Casy si-i spuse: "ei a sre ae
# — Dumneata ai mai avut de-a face cu oameni bolnayj a casy-
# Bunului ii e rau, n-ai vrea s& vezi ce-o fi avind? i 1s? crede# c
# Casy se indrepta repede inspre cort si intra. Pe pamint =~ Casy |
# se afla o saltea dubla, acoperita de p&turi intinse cu erija; ‘ jos 13
# focul ardea molcom intr-o soba mica de tabla cu picioare de afar’
# tuci. Mai erau acolo o galeata cu apa, o ladita de lemn eu aati
# citeva alimente si o ladda mai mArisoara, care tinea loc de i rast
# masa — atita tot. Lumina rosiaticd a soarelui in asfintit se Apo. "
# strecura prin pinza cortului. Bunul zacea intins pe spate si : =~ Bin a
# Sairy Wilson ingenunche linga saltea, la capatiiul lui. Ochii {ne de got
# bolnavului stateau deschisi si priveau drept in sus, iar obra- 3 pone
# jii se-mbujorasera de fierbinteala. Respira cu greutate. privi in Jos
# Casy prinse intre degete incheietura batrina si descarnata — Ce-i
# a miinii unchiasului. virile bolr
# — Te simti obosit rau, bunule? il intreba el. ise fram:
# Ochii batrinului privira inspre locul de unde venea glasul, c&iun a
# dar nu il deslugira pe Casy. Buzele i se migcara, dar nu se sh ny
# auzi nici o vorba. Casy ii lua pulsul, apoi lasa incheietura Se pling
# miinii si fi puse palms pe frunte. Un freamat se stirni in Pe supa
#
# trupul unchiagului, r k é- mic Zhe Bervos miin
# ise agitara. Scoaseg .
#
# oa
# cuvinte, gi fata fi "
